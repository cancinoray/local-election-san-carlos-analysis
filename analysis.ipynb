# %%
import requests
import os
import json
import pandas as pd
import re
from collections import defaultdict

import matplotlib.pyplot as plt
import numpy as np

# %%
# Step 1: Get the initial data
response = requests.get("https://2025electionresults.comelec.gov.ph/data/regions/local/5532000.json")
data = response.json()

# Step 2: Extract all the codes from the regions
codes = [region['code'] for region in data["regions"]]

# Step 3: Create a folder to store the JSON files (if it doesn't exist)
os.makedirs('data', exist_ok=True)

# Step 4: Loop through the codes and fetch the data
for code in codes:
    url = f"https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/{code}.json"
    response_barangay = requests.get(url)
    data_barangay = response_barangay.json()

    # Extract the 'code' from the new data
    barangay_codes = [barangay['code'] for barangay in data_barangay["regions"]]

    # Step 5: Loop through each barangay code and save the data
    for barangay_code in barangay_codes:
        url = f"https://2025electionresults.comelec.gov.ph/data/er/553/{barangay_code}.json"
        print(f"Fetching: {url}")
        
        # Fetch the data from the final URL
        response_final = requests.get(url)
        
        if response_final.status_code == 200:
            data_final = response_final.json()
            
            # Extract voting center and remove "barangay" prefix if it exists
            voting_center = data_final["information"]["votingCenter"].lower().replace(" ", "-")
            voting_center = voting_center.replace("barangay-", "")

            # Step 6: Check if the file already exists, and append a counter if it does
            filename = f'data/{voting_center}.json'
            counter = 2
            while os.path.exists(filename):
                filename = f'data/{voting_center}_{counter}.json'
                counter += 1
            
            # Step 7: Save the data to the JSON file
            with open(filename, 'w', encoding='utf-8') as file:
                json.dump(data_final, file, ensure_ascii=False, indent=4)
                
            print(f"Saved: {filename}")
        else:
            print(f"Failed to fetch data for {barangay_code}")
# Out:
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320020.json
# Saved: data/abanon.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320021.json
# Saved: data/abanon_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320022.json
# Saved: data/agdao.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320023.json
# Saved: data/agdao_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320024.json
# Saved: data/agdao_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320025.json
# Saved: data/libas.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320026.json
# Saved: data/ano.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320027.json
# Saved: data/ano_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320028.json
# Saved: data/antipangol.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320029.json
# Saved: data/antipangol_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320030.json
# Saved: data/aponit.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320031.json
# Saved: data/aponit_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320032.json
# Saved: data/bacnar.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320033.json
# Saved: data/bacnar_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320034.json
# Saved: data/bacnar_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320035.json
# Saved: data/bacnar_4.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320036.json
# Saved: data/balaya.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320037.json
# Saved: data/balaya_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320038.json
# Saved: data/balayong.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320039.json
# Saved: data/balayong_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320040.json
# Saved: data/baldog.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320041.json
# Saved: data/baldog_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320042.json
# Saved: data/balite-sur.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320043.json
# Saved: data/balite-sur_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320044.json
# Saved: data/balite-sur_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320045.json
# Saved: data/balococ.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320046.json
# Saved: data/balococ_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320047.json
# Saved: data/bani.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320048.json
# Saved: data/tarece.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320049.json
# Saved: data/tarece_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320050.json
# Saved: data/bocboc.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320006.json
# Saved: data/roxas-blvd..json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320051.json
# Saved: data/bogaoan.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320052.json
# Saved: data/bogaoan_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320053.json
# Saved: data/bolingit.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320054.json
# Saved: data/bolingit_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320055.json
# Saved: data/bolingit_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320056.json
# Saved: data/bolosan.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320057.json
# Saved: data/bolosan_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320002.json
# Saved: data/roxas-blvd._2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320058.json
# Saved: data/buenglat.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320059.json
# Saved: data/buenglat_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320005.json
# Saved: data/roxas-blvd._3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320060.json
# Saved: data/roxas-blvd._4.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320061.json
# Saved: data/roxas-blvd._5.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320062.json
# Saved: data/bolosan_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320063.json
# Saved: data/bolosan_4.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320064.json
# Saved: data/calobaoan.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320065.json
# Saved: data/calobaoan_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320066.json
# Saved: data/calobaoan_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320067.json
# Saved: data/calomboyan.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320068.json
# Saved: data/calomboyan_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320069.json
# Saved: data/calomboyan_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320070.json
# Saved: data/pangalangan.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320071.json
# Saved: data/pangalangan_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320072.json
# Saved: data/caoayan-kiling.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320073.json
# Saved: data/caoayan-kiling_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320074.json
# Saved: data/caoayan-kiling_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320075.json
# Saved: data/cobol.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320076.json
# Saved: data/cobol_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320077.json
# Saved: data/cobol_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320078.json
# Saved: data/coliling.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320079.json
# Saved: data/coliling_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320080.json
# Saved: data/coliling_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320081.json
# Saved: data/coliling_4.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320082.json
# Saved: data/cruz.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320083.json
# Saved: data/cruz_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320084.json
# Saved: data/doyong.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320085.json
# Saved: data/doyong_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320086.json
# Saved: data/gamata.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320087.json
# Saved: data/gamata_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320088.json
# Saved: data/guelew.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320089.json
# Saved: data/guelew_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320090.json
# Saved: data/guelew_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320091.json
# Saved: data/roxas-blvd._6.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320092.json
# Saved: data/inerangan.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320093.json
# Saved: data/inerangan_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320094.json
# Saved: data/isla.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320095.json
# Saved: data/isla_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320096.json
# Saved: data/libas_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320097.json
# Saved: data/libas_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320098.json
# Saved: data/libas_4.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320099.json
# Saved: data/lilimasan.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320100.json
# Saved: data/lilimasan_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320101.json
# Saved: data/roxas-blvd._7.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320007.json
# Saved: data/roxas-blvd._8.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320102.json
# Saved: data/mabalbalino.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320103.json
# Saved: data/mabalbalino_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320015.json
# Saved: data/roxas-blvd._9.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320104.json
# Saved: data/magtaking.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320105.json
# Saved: data/magtaking_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320106.json
# Saved: data/malacañang.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320107.json
# Saved: data/malacañang_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320108.json
# Saved: data/malacañang_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320109.json
# Saved: data/maliwara.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320110.json
# Saved: data/roxas-blvd._10.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320111.json
# Saved: data/roxas-blvd._11.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320112.json
# Saved: data/bolingit_4.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320113.json
# Saved: data/bolingit_5.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320114.json
# Saved: data/matagdem.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320115.json
# Saved: data/matagdem_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320116.json
# Saved: data/matagdem_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320117.json
# Saved: data/mestizo-norte.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320118.json
# Saved: data/mestizo-norte_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320119.json
# Saved: data/naguilayan.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320120.json
# Saved: data/naguilayan_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320121.json
# Saved: data/nelintap.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320122.json
# Saved: data/nelintap_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320018.json
# Saved: data/roxas-blvd._12.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320019.json
# Saved: data/roxas-blvd._13.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320123.json
# Saved: data/pagal.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320124.json
# Saved: data/pagal_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320125.json
# Saved: data/pagal_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320128.json
# Saved: data/palaming.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320129.json
# Saved: data/palaming_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320001.json
# Saved: data/roxas-blvd._14.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320130.json
# Saved: data/palospos.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320131.json
# Saved: data/pangalangan_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320132.json
# Saved: data/pangalangan_4.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320133.json
# Saved: data/pangalangan_5.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320134.json
# Saved: data/pangoloan.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320135.json
# Saved: data/pangoloan_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320136.json
# Saved: data/pangpang.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320137.json
# Saved: data/pangpang_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320138.json
# Saved: data/pangpang_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320126.json
# Saved: data/magtaking_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320127.json
# Saved: data/magtaking_4.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320139.json
# Saved: data/parayao.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320140.json
# Saved: data/payapa.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320141.json
# Saved: data/payapa_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320142.json
# Saved: data/payar.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320143.json
# Saved: data/payar_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320016.json
# Saved: data/roxas-blvd._15.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320144.json
# Saved: data/polo.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320145.json
# Saved: data/polo_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320013.json
# Saved: data/roxas-blvd._16.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320014.json
# Saved: data/roxas-blvd._17.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320146.json
# Saved: data/quintong.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320147.json
# Saved: data/quintong_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320148.json
# Saved: data/quintong_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320009.json
# Saved: data/roxas-blvd._18.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320010.json
# Saved: data/roxas-blvd._19.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320008.json
# Saved: data/roxas-blvd._20.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320149.json
# Saved: data/salinap.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320150.json
# Saved: data/salinap_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320151.json
# Saved: data/san-juan.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320152.json
# Saved: data/san-juan_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320153.json
# Saved: data/san-juan_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320003.json
# Saved: data/roxas-blvd._21.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320004.json
# Saved: data/roxas-blvd._22.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320154.json
# Saved: data/sapinit.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320155.json
# Saved: data/sapinit_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320012.json
# Saved: data/roxas-blvd._23.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320156.json
# Saved: data/supo.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320157.json
# Saved: data/talang.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320158.json
# Saved: data/talang_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320159.json
# Saved: data/tamayo.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320160.json
# Saved: data/tamayo_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320161.json
# Saved: data/tandoc.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320162.json
# Saved: data/tandoc_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320163.json
# Saved: data/tandoc_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320164.json
# Saved: data/tarece_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320165.json
# Saved: data/tarece_4.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320166.json
# Saved: data/tarece_5.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320167.json
# Saved: data/tarectec.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320168.json
# Saved: data/tarectec_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320169.json
# Saved: data/talang_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320170.json
# Saved: data/tebag.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320171.json
# Saved: data/turac.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320172.json
# Saved: data/turac_2.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320173.json
# Saved: data/turac_3.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320174.json
# Saved: data/turac_4.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320017.json
# Saved: data/roxas-blvd._24.json
# Fetching: https://2025electionresults.comelec.gov.ph/data/er/553/55320011.json
# Saved: data/roxas-blvd._25.json

# %%
def aggregate_barangay_data(data_folder):
    """
    Load and aggregate barangay JSON files, combining data for the same barangay
    from multiple files (like barangay.json, barangay_2.json).
    """
    # Dictionary to hold aggregated data by barangay and candidate
    aggregated_votes = defaultdict(int)
    barangay_info = {}
    
    # Get all JSON files in the data folder
    json_files = [f for f in os.listdir(data_folder) if f.endswith('.json')]
    
    for file_name in json_files:
        file_path = os.path.join(data_folder, file_name)
        
        # Extract base barangay name (remove _2, _3 suffixes if present)
        base_barangay = re.sub(r'_\d+\.json$', '', file_name)
        base_barangay = base_barangay.replace('.json', '')
        
        # Read JSON data
        with open(file_path, 'r') as file:
            data = json.load(file)
        
        # Store barangay information
        if base_barangay not in barangay_info:
            barangay_info[base_barangay] = {
                'location': data['information']['location'],
                'precinct_id': data['information']['precinctId'],
                'registered_voters': data['information']['numberOfRegisteredVoters'],
                'actual_voters': data['information']['numberOfActuallyVoters'],
                'turnout': data['information']['turnout']
            }
        
        # Process national contests
        for contest in data['national']:
            contest_name = contest['contestName']
            
            for candidate in contest['candidates']['candidates']:
                key = (base_barangay, 'National', contest_name, candidate['name'])
                aggregated_votes[key] += candidate['votes']
        
        # Process local contests
        for contest in data['local']:
            contest_name = contest['contestName']
            
            for candidate in contest['candidates']['candidates']:
                key = (base_barangay, 'Local', contest_name, candidate['name'])
                aggregated_votes[key] += candidate['votes']
    
    # Convert aggregated data to DataFrame format
    results = []
    for (barangay, contest_type, contest_name, candidate_name), votes in aggregated_votes.items():
        results.append({
            'barangay': barangay,
            'location': barangay_info[barangay]['location'],
            'precinct_id': barangay_info[barangay]['precinct_id'],
            'registered_voters': barangay_info[barangay]['registered_voters'],
            'actual_voters': barangay_info[barangay]['actual_voters'],
            'turnout': barangay_info[barangay]['turnout'],
            'contest_type': contest_type,
            'contest_name': contest_name,
            'candidate_name': candidate_name,
            'votes': votes
        })
    
    df = pd.DataFrame(results)
    
    # Calculate percentage for each candidate within their contest and barangay
    contest_total_votes = df.groupby(['barangay', 'contest_type', 'contest_name'])['votes'].transform('sum')
    df['percentage'] = (df['votes'] / contest_total_votes) * 100
    df['percentage'] = df['percentage'].round(2)
    
    return df

def main():
    # Replace with your data folder path
    data_folder = "data"
    
    # Aggregate barangay data
    df = aggregate_barangay_data(data_folder)
    
    # Display basic information
    print(f"Total candidates across all barangays: {len(df)}")
    print(f"Unique barangays: {df['barangay'].nunique()}")
    
    # Top candidates per contest (aggregated across all barangays)
    print("\nTop 5 candidates for Senator position:")
    senator_results = df[df['contest_name'] == 'SENATOR of PHILIPPINES']
    top_senators = senator_results.groupby('candidate_name')['votes'].sum().reset_index()
    top_senators = top_senators.sort_values('votes', ascending=False).head(5)
    print(top_senators)
    
    # Party List results
    print("\nTop 5 Party List results:")
    party_results = df[df['contest_name'] == 'PARTY LIST of PHILIPPINES']
    top_parties = party_results.groupby('candidate_name')['votes'].sum().reset_index()
    top_parties = top_parties.sort_values('votes', ascending=False).head(5)
    print(top_parties)
    
    # Save to CSV
    df.to_csv('aggregated_election_results.csv', index=False)
    print("\nAggregated data saved to 'aggregated_election_results.csv'")

if __name__ == "__main__":
    main()
# Out:
# Total candidates across all barangays: 15860
# Unique barangays: 61
#
# Top 5 candidates for Senator position:
#               candidate_name  votes
# 44      5. AQUINO, BAM (KNP)  51346
# 54     59. SOTTO, TITO (NPC)  45514
# 59  63. TULFO, ERWIN (LAKAS)  44365
# 0    1. ABALOS, BENHUR (PFP)  41272
# 9     18. CAYETANO, PIA (NP)  40018
#
# Top 5 Party List results:
#              candidate_name  votes
# 79   3 FPJ PANDAY BAYANIHAN  17145
# 13                110 ABONO   9493
# 26        122 PINOY WORKERS   6406
# 6     104 SOLID NORTH PARTY   5479
# 103              51 AKBAYAN   5337
#
# Aggregated data saved to 'aggregated_election_results.csv'

# %%
def create_contest_datasets(data_folder):
    """
    Create separate datasets for each contest with:
    - Candidates in rows (left side)
    - Barangays in columns (headers)
    - Vote counts in cells (aggregated across multiple files for the same barangay)
    
    Returns a tuple of (contest_datasets, all_barangays)
    """
    # Dictionary to store votes by contest, candidate, and barangay
    contest_data = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
    
    # List to track all barangays and contests we encounter
    all_barangays = set()
    all_contests = set()
    
    # Get all JSON files in the data folder
    json_files = [f for f in os.listdir(data_folder) if f.endswith('.json')]
    
    # Process each file
    for file_name in json_files:
        file_path = os.path.join(data_folder, file_name)
        
        # Extract base barangay name (remove _2, _3 suffixes if present)
        base_barangay = re.sub(r'_\d+\.json$', '', file_name)
        base_barangay = base_barangay.replace('.json', '')
        all_barangays.add(base_barangay)
        
        # Read JSON data
        with open(file_path, 'r') as file:
            data = json.load(file)
        
        # Process national contests
        for contest in data['national']:
            contest_name = contest['contestName']
            all_contests.add(contest_name)
            
            # Process each candidate
            for candidate in contest['candidates']['candidates']:
                # Add votes for this candidate in this barangay
                # Using defaultdict(int) ensures we're adding to the existing count
                contest_data[contest_name][candidate['name']][base_barangay] += candidate['votes']
        
        # Process local contests
        for contest in data['local']:
            contest_name = contest['contestName']
            all_contests.add(contest_name)
            
            # Process each candidate
            for candidate in contest['candidates']['candidates']:
                # Add votes for this candidate in this barangay
                contest_data[contest_name][candidate['name']][base_barangay] += candidate['votes']
    
    # Convert to DataFrames
    dataframes = {}
    all_barangays_list = sorted(list(all_barangays))
    
    for contest_name in all_contests:
        # Create a list of dictionaries (one per candidate)
        rows = []
        for candidate_name, barangay_votes in contest_data[contest_name].items():
            # Start with the candidate name
            row = {'Candidate': candidate_name}
            
            # Add votes for each barangay
            for barangay in all_barangays_list:
                row[barangay] = barangay_votes.get(barangay, 0)
            
            # Add a total column
            row['Total'] = sum(barangay_votes.values())
            
            rows.append(row)
        
        # Create DataFrame and sort by total votes
        df = pd.DataFrame(rows)
        if not df.empty:
            df = df.sort_values('Total', ascending=False)
            
            # Move Candidate column to the front
            candidate_col = df.pop('Candidate')
            df.insert(0, 'Candidate', candidate_col)
        
        # Store in our dictionary of dataframes
        dataframes[contest_name] = df
    
    # Return both the dataframes and the list of barangays
    return dataframes, all_barangays_list

def main():
    # Replace with your data folder path
    data_folder = "data"
    
    # Create results folder if it doesn't exist
    results_folder = "./results-per-position"
    if not os.path.exists(results_folder):
        os.makedirs(results_folder)
        print(f"Created directory: {results_folder}")
    
    # Create contest datasets and get the list of barangays
    contest_datasets, all_barangays = create_contest_datasets(data_folder)
    
    # Display summary
    print(f"Created {len(contest_datasets)} contest datasets\n")
    
    # Display each dataset (or just the first few rows)
    for contest_name, df in contest_datasets.items():
        print(f"Dataset: {contest_name}")
        print(f"Shape: {df.shape[0]} candidates × {df.shape[1]} columns")
        print(df.head(5))  # Show top 5 candidates
        print("\n" + "="*50 + "\n")
        
        # Save to CSV in the results folder
        clean_name = re.sub(r'[^\w\s]', '', contest_name).replace(' ', '_')
        filename = os.path.join(results_folder, f"{clean_name}_results.csv")
        df.to_csv(filename, index=False)
        print(f"Saved to {filename}")
        print("\n")

    # Create a summary DataFrame of total votes per barangay
    barangay_summary = pd.DataFrame(index=all_barangays)
    for contest_name, df in contest_datasets.items():
        if 'Total' in df.columns:
            # Save the contest totals without the 'Candidate' column
            contest_cols = [col for col in df.columns if col not in ['Candidate', 'Total']]
            contest_totals = df[contest_cols].sum()
            barangay_summary[contest_name] = contest_totals
    
    # Add total votes column
    barangay_summary['Total Votes'] = barangay_summary.sum(axis=1)
    
    # Save summary to the results folder
    summary_filename = os.path.join(results_folder, 'barangay_vote_summary.csv')
    barangay_summary.to_csv(summary_filename)
    print(f"Saved barangay summary to '{summary_filename}'")

if __name__ == "__main__":
    main()
# Out:
# Created directory: ./results-per-position
# Created 9 contest datasets
#
# Dataset: SENATOR of PHILIPPINES
# Shape: 66 candidates × 63 columns
#                    Candidate  abanon  agdao  ano  antipangol  aponit  bacnar  \
# 4       5. AQUINO, BAM (KNP)     564   1026  711         400     505    1393
# 58     59. SOTTO, TITO (NPC)     441    893  596         434     487    1271
# 62  63. TULFO, ERWIN (LAKAS)     449    790  687         455     469    1259
# 0    1. ABALOS, BENHUR (PFP)     446    804  569         354     479    1056
# 17    18. CAYETANO, PIA (NP)     402    781  581         392     414    1105
#
#     balaya  balayong  baldog  ...  sapinit  supo  talang  tamayo  tandoc  \
# 4      459       521     562  ...      388   366     807     586     892
# 58     441       475     471  ...      352   323     699     672     794
# 62     428       455     452  ...      349   313     729     678     811
# 0      385       408     475  ...      337   270     694     609     825
# 17     374       437     412  ...      301   313     643     537     617
#
#     tarece  tarectec  tebag  turac  Total
# 4     1818       470    394   1495  51346
# 58    1512       374    340   1345  45514
# 62    1431       352    300   1258  44365
# 0     1426       368    318   1261  41272
# 17    1343       348    266   1123  40018
#
# [5 rows x 63 columns]
#
# ==================================================
#
# Saved to ./results-per-position/SENATOR_of_PHILIPPINES_results.csv
#
#
# Dataset: PARTY LIST of PHILIPPINES
# Shape: 155 candidates × 63 columns
#                   Candidate  abanon  agdao  ano  antipangol  aponit  bacnar  \
# 2    3 FPJ PANDAY BAYANIHAN     182    228  171         162     197     408
# 108               110 ABONO     139    432   37         176     241     136
# 120       122 PINOY WORKERS     139     39   23          14      73     165
# 102   104 SOLID NORTH PARTY      75     44   76          30      46      62
# 50               51 AKBAYAN      43    102   74          23      39     110
#
#      balaya  balayong  baldog  ...  sapinit  supo  talang  tamayo  tandoc  \
# 2       209       179     114  ...      151   112     305     202     405
# 108      54        17     173  ...       27   161     288     312      47
# 120     121       122      80  ...      113    89     175      23      84
# 102      15        50     178  ...        6    55      49      10      65
# 50       42        57      72  ...       63    31      83      46      98
#
#      tarece  tarectec  tebag  turac  Total
# 2       385       165    129    208  17145
# 108     463        30    127    504   9493
# 120      63        53     16    139   6406
# 102     146        80     51    220   5479
# 50      226        58     36    153   5337
#
# [5 rows x 63 columns]
#
# ==================================================
#
# Saved to ./results-per-position/PARTY_LIST_of_PHILIPPINES_results.csv
#
#
# Dataset: MAYOR of PANGASINAN - CITY OF SAN CARLOS
# Shape: 2 candidates × 63 columns
#                   Candidate  abanon  agdao  ano  antipangol  aponit  bacnar  \
# 0    1. RESUELLO, AYOY (NP)     581   1034  604         665     732    1622
# 1  2. SORIANO, LESTER (NPC)     534    978  946         357     524    1131
#
#    balaya  balayong  baldog  ...  sapinit  supo  talang  tamayo  tandoc  \
# 0     695       681     570  ...      414   416     871     896    1096
# 1     388       413     645  ...      457   379     907     728     774
#
#    tarece  tarectec  tebag  turac  Total
# 0    1914       546    479   1588  58261
# 1    1579       374    300   1439  48758
#
# [2 rows x 63 columns]
#
# ==================================================
#
# Saved to ./results-per-position/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_results.csv
#
#
# Dataset: MEMBER, SANGGUNIANG PANLUNGSOD of PANGASINAN - CITY OF SAN CARLOS - LONE DIST
# Shape: 23 candidates × 63 columns
#                      Candidate  abanon  agdao  ano  antipangol  aponit  \
# 3        4. BANIQUED, SAM (NP)     657    957  857         617     592
# 8         9. FERMIN, BIDO (NP)     439   1032  651         539     513
# 7     8. CANO, KUYA NICK (NPC)     559   1142  646         493     545
# 6   7. CANCINO, CHRISTIAN (NP)     349    918  720         558     709
# 10      11. GARCIA, MANOY (NP)     472    943  621         650     869
#
#     bacnar  balaya  balayong  baldog  ...  sapinit  supo  talang  tamayo  \
# 3     1624     628       598     448  ...      439   440     769     761
# 8     1452     551       623     508  ...      324   350     639     672
# 7     1485     466       522     633  ...      298   446     756     852
# 6     1113     663       665     884  ...      307   264    1059     745
# 10    1316     573       453     679  ...      345   397    1031     959
#
#     tandoc  tarece  tarectec  tebag  turac  Total
# 3      876    1822       478    435   2029  54049
# 8      999    1731       390    358   1279  50954
# 7      940    1564       467    350   1164  50218
# 6      920    1725       322    311    808  49862
# 10     629    1622       347    309   1099  49664
#
# [5 rows x 63 columns]
#
# ==================================================
#
# Saved to ./results-per-position/MEMBER_SANGGUNIANG_PANLUNGSOD_of_PANGASINAN__CITY_OF_SAN_CARLOS__LONE_DIST_results.csv
#
#
# Dataset: MEMBER, HOUSE OF REPRESENTATIVES of PANGASINAN - THIRD LEGDIST
# Shape: 3 candidates × 63 columns
#                         Candidate  abanon  agdao   ano  antipangol  aponit  \
# 1  2. ARENAS, RACHEL BABY (LAKAS)    1024   1689  1404         913    1056
# 2         3. TULAGAN, GENER (IND)      38    163    64          41      79
# 0        1. ABSOLOR, GEORGE (IND)       9     52    20          12      20
#
#    bacnar  balaya  balayong  baldog  ...  sapinit  supo  talang  tamayo  \
# 1    2470     982       971    1021  ...      751   701    1374    1331
# 2     148      29        65     125  ...       60    58     298     101
# 0      30      14         8      15  ...        6     9      29      39
#
#    tandoc  tarece  tarectec  tebag  turac  Total
# 1    1650    2973       808    681   2677  91987
# 2      99     275        57     58    145   7495
# 0      27      58        12     10     40   1877
#
# [3 rows x 63 columns]
#
# ==================================================
#
# Saved to ./results-per-position/MEMBER_HOUSE_OF_REPRESENTATIVES_of_PANGASINAN__THIRD_LEGDIST_results.csv
#
#
# Dataset: MEMBER, SANGGUNIANG PANLALAWIGAN of PANGASINAN - THIRD PROVDIST
# Shape: 5 candidates × 63 columns
#                         Candidate  abanon  agdao   ano  antipangol  aponit  \
# 0   1. BANIQUED, DRA. SHIELA (NP)     839   1356  1107         771     830
# 4        5. VENTANILLA, VICI (NP)     759   1150   713         523     683
# 3  4. TULAGAN, GENEROSO JR. (NPC)     147    461   240         110     190
# 1   2. BAUZON, JOSEPH ARMAN (API)      60    299   477         273     174
# 2      3. GONZALES, EDUARDO (IND)      31     51    52          25      36
#
#    bacnar  balaya  balayong  baldog  ...  sapinit  supo  talang  tamayo  \
# 0    1925     697       768     791  ...      555   606    1056    1070
# 4    1789     761       608     710  ...      661   513     918     960
# 3     530     134       182     286  ...      110   129     556     205
# 1     359     121       234     229  ...       61    91     312     190
# 2      61      32        24      30  ...        8    18      48      44
#
#    tandoc  tarece  tarectec  tebag  turac  Total
# 0    1199    2489       698    543   2178  73498
# 4    1092    1855       555    354   1752  61853
# 3     274     731       177    138    485  20479
# 1     432     635       136    223    502  16525
# 2      47      71        10     21     72   2751
#
# [5 rows x 63 columns]
#
# ==================================================
#
# Saved to ./results-per-position/MEMBER_SANGGUNIANG_PANLALAWIGAN_of_PANGASINAN__THIRD_PROVDIST_results.csv
#
#
# Dataset: PROVINCIAL GOVERNOR of PANGASINAN
# Shape: 2 candidates × 63 columns
#                     Candidate  abanon  agdao   ano  antipangol  aponit  \
# 0  1. ESPINO, AMADO III (API)     545   1146  1075         569     658
# 1    2. GUICO, RAMON III (NP)     552    832   453         434     560
#
#    bacnar  balaya  balayong  baldog  ...  sapinit  supo  talang  tamayo  \
# 0    1594     645       671     664  ...      543   386     879     956
# 1    1128     413       403     515  ...      316   396     855     605
#
#    tandoc  tarece  tarectec  tebag  turac  Total
# 0    1132    2079       582    500   1845  62580
# 1     713    1353       324    265   1115  42277
#
# [2 rows x 63 columns]
#
# ==================================================
#
# Saved to ./results-per-position/PROVINCIAL_GOVERNOR_of_PANGASINAN_results.csv
#
#
# Dataset: VICE-MAYOR of PANGASINAN - CITY OF SAN CARLOS
# Shape: 2 candidates × 63 columns
#                    Candidate  abanon  agdao  ano  antipangol  aponit  bacnar  \
# 1     2. RESUELLO, BOGS (NP)     602   1022  627         668     738    1605
# 0  1. LOMBOY, JONATHAN (NPC)     497    974  901         341     485    1130
#
#    balaya  balayong  baldog  ...  sapinit  supo  talang  tamayo  tandoc  \
# 1     744       748     527  ...      459   439     875     846    1165
# 0     335       338     671  ...      400   347     880     750     682
#
#    tarece  tarectec  tebag  turac  Total
# 1    2102       571    480   1815  59903
# 0    1361       348    290   1171  45881
#
# [2 rows x 63 columns]
#
# ==================================================
#
# Saved to ./results-per-position/VICEMAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_results.csv
#
#
# Dataset: PROVINCIAL VICE-GOVERNOR of PANGASINAN
# Shape: 2 candidates × 63 columns
#                   Candidate  abanon  agdao  ano  antipangol  aponit  bacnar  \
# 0  1. LAMBINO, MARK (LAKAS)     742   1292  960         593     791    1780
# 1      2. NACAR, NOEL (API)     201    462  351         267     204     602
#
#    balaya  balayong  baldog  ...  sapinit  supo  talang  tamayo  tandoc  \
# 0     684       696     760  ...      543   565    1152     910    1150
# 1     229       213     243  ...      173   117     296     337     406
#
#    tarece  tarectec  tebag  turac  Total
# 0    2254       637    455   1861  67244
# 1     651       163    183    665  22345
#
# [2 rows x 63 columns]
#
# ==================================================
#
# Saved to ./results-per-position/PROVINCIAL_VICEGOVERNOR_of_PANGASINAN_results.csv
#
#
# Saved barangay summary to './results-per-position/barangay_vote_summary.csv'

# %%
def create_mayor_graphs(results_folder="./results-per-position"):
    """
    Create line and bar graphs showing mayoral votes per barangay
    """
    # Use the exact filename from the screenshot
    mayor_file = os.path.join(results_folder, "MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_results.csv")
    
    # Check if the file exists
    if not os.path.exists(mayor_file):
        print(f"Error: File does not exist: {mayor_file}")
        # List all files in the directory to debug
        print("Files in the directory:")
        for file in os.listdir(results_folder):
            print(f"  - {file}")
        return
    
    print(f"Found mayor file: {mayor_file}")
    contest_name = "MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS"
    
    # Load the mayor data
    mayor_df = pd.read_csv(mayor_file)
    
    # Get the candidate and barangay columns
    candidates = mayor_df['Candidate'].tolist()
    
    # Simplify candidate names for better display (just get the name part)
    simplified_names = []
    for name in candidates:
        # Extract the name part between the number and the parenthesis
        match = re.search(r'\d+\.\s+(.*?)\s+\(', name)
        if match:
            simplified_names.append(match.group(1))
        else:
            simplified_names.append(name)
    
    # Get barangay columns (exclude 'Candidate' and 'Total')
    barangays = [col for col in mayor_df.columns if col not in ['Candidate', 'Total']]
    
    # Transpose the data for plotting (exclude 'Candidate' and 'Total' columns)
    plot_data = mayor_df[barangays].copy()
    plot_data.index = simplified_names
    
    # Create directory for graphs if it doesn't exist
    graphs_folder = os.path.join(results_folder, 'graphs')
    if not os.path.exists(graphs_folder):
        os.makedirs(graphs_folder)
        print(f"Created directory: {graphs_folder}")
    
    # Generate a clean name for filenames
    clean_contest = re.sub(r'[^\w\s]', '', contest_name).replace(' ', '_')
    
    # ========== LINE GRAPH ==========
    plt.figure(figsize=(14, 8))
    
    # Plot each candidate as a line
    for i, candidate in enumerate(simplified_names):
        plt.plot(barangays, plot_data.loc[candidate], marker='o', linewidth=2, 
                 label=candidate, markersize=8)
    
    # Add labels and title
    plt.title('Mayoral Votes per Barangay (Line Graph)', fontsize=16)
    plt.xlabel('Barangay', fontsize=14)
    plt.ylabel('Number of Votes', fontsize=14)
    plt.xticks(rotation=45, ha='right', fontsize=12)
    plt.legend(title='Candidates', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Adjust layout and save
    plt.tight_layout()
    line_graph_path = os.path.join(graphs_folder, f'{clean_contest}_line_graph.png')
    plt.savefig(line_graph_path, dpi=300)
    plt.close()
    print(f"Saved line graph to: {line_graph_path}")
    
    # ========== BAR GRAPH ==========
    plt.figure(figsize=(14, 8))
    
    # Set the positions for the bars
    bar_width = 0.8 / len(candidates)
    positions = np.arange(len(barangays))
    
    # Plot each candidate as a group of bars
    for i, candidate in enumerate(simplified_names):
        offset = i * bar_width - (len(candidates) * bar_width / 2) + (bar_width / 2)
        bars = plt.bar(positions + offset, plot_data.loc[candidate], 
                        width=bar_width, label=candidate)
    
    # Add labels and title
    plt.title('Mayoral Votes per Barangay (Bar Graph)', fontsize=16)
    plt.xlabel('Barangay', fontsize=14)
    plt.ylabel('Number of Votes', fontsize=14)
    plt.xticks(positions, barangays, rotation=45, ha='right', fontsize=12)
    plt.legend(title='Candidates', fontsize=12)
    plt.grid(True, axis='y', linestyle='--', alpha=0.7)
    
    # Adjust layout and save
    plt.tight_layout()
    bar_graph_path = os.path.join(graphs_folder, f'{clean_contest}_bar_graph.png')
    plt.savefig(bar_graph_path, dpi=300)
    plt.close()
    print(f"Saved bar graph to: {bar_graph_path}")
    
    # ========== GROUPED BAR GRAPH (Alternative View) ==========
    plt.figure(figsize=(14, 8))
    
    # Transpose for grouped bar chart
    stacked_data = plot_data.T
    
    # Create grouped bar chart
    stacked_data.plot(kind='bar', stacked=False, figsize=(14, 8))
    
    # Add labels and title
    plt.title('Mayoral Votes per Barangay (Grouped Bar Graph)', fontsize=16)
    plt.xlabel('Barangay', fontsize=14)
    plt.ylabel('Number of Votes', fontsize=14)
    plt.xticks(rotation=45, ha='right', fontsize=12)
    plt.legend(title='Candidates', fontsize=12)
    plt.grid(True, axis='y', linestyle='--', alpha=0.7)
    
    # Adjust layout and save
    plt.tight_layout()
    grouped_bar_path = os.path.join(graphs_folder, f'{clean_contest}_grouped_bar_graph.png')
    plt.savefig(grouped_bar_path, dpi=300)
    plt.close()
    print(f"Saved grouped bar graph to: {grouped_bar_path}")

# Create the graphs
create_mayor_graphs("./results-per-position")
# Out:
# Found mayor file: ./results-per-position/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_results.csv
# Saved line graph to: ./results-per-position/graphs/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_line_graph.png
# Saved bar graph to: ./results-per-position/graphs/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_bar_graph.png
# Saved grouped bar graph to: ./results-per-position/graphs/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_grouped_bar_graph.png
