# %%
import requests
import os
import json
import pandas as pd
import re
from collections import defaultdict
import time
from pathlib import Path
from requests.exceptions import RequestException
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.cm as cm
from matplotlib.colors import Normalize
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import seaborn as sns

# %%
# Step 1: Create folder to store data
os.makedirs('data', exist_ok=True)

# Step 2: Get the initial data with error handling
try:
    response = requests.get("https://2025electionresults.comelec.gov.ph/data/regions/local/5532000.json")
    response.raise_for_status()  # Raise exception for non-200 status codes
    data = response.json()
except RequestException as e:
    print(f"Failed to get initial data: {e}")
    exit(1)
except json.JSONDecodeError:
    print("Failed to decode initial JSON data")
    exit(1)

# Step 3: Extract all the codes from the regions with validation
if "regions" not in data:
    print("Expected 'regions' key not found in data")
    exit(1)

codes = [region.get('code') for region in data["regions"] if region.get('code')]
print(f"Found {len(codes)} region codes")

# Step 4: Loop through the codes and fetch the data
for code in codes:
    try:
        url = f"https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/{code}.json"
        print(f"Fetching barangay data from: {url}")
        response_barangay = requests.get(url)
        response_barangay.raise_for_status()
        data_barangay = response_barangay.json()
        
        # Add delay to prevent rate limiting
        time.sleep(1)
        
        # Extract the 'code' from the new data with validation
        if "regions" not in data_barangay:
            print(f"No 'regions' key found for code {code}")
            continue
            
        barangay_codes = [barangay.get('code') for barangay in data_barangay["regions"] if barangay.get('code')]
        print(f"Found {len(barangay_codes)} barangay codes for region {code}")
        
        # Step 5: Loop through each barangay code and save the data
        for barangay_code in barangay_codes:
            # Try multiple URL patterns if the first one fails
            urls_to_try = [
                f"https://2025electionresults.comelec.gov.ph/data/er/553/{barangay_code}.json",
                f"https://2025electionresults.comelec.gov.ph/data/er/55/{barangay_code}.json",
                f"https://2025electionresults.comelec.gov.ph/data/er/{code}/{barangay_code}.json"
            ]
            
            success = False
            for url in urls_to_try:
                try:
                    print(f"Trying: {url}")
                    response_final = requests.get(url)
                    response_final.raise_for_status()
                    data_final = response_final.json()
                    
                    # Validate the expected data structure
                    if "information" not in data_final or "location" not in data_final["information"]:
                        print(f"Missing expected data structure in response from {url}")
                        continue
                    
                    # Extract location and get the last part (barangay name)
                    location = data_final["information"]["location"]
                    location_last_part = location.split(',')[-1].strip().lower().replace(" ", "-")
                    
                    # Save with barangay code to ensure uniqueness
                    filename = f'data/{location_last_part}_{barangay_code}.json'
                    counter = 2
                    while os.path.exists(filename):
                        filename = f'data/{location_last_part}_{barangay_code}_{counter}.json'
                        counter += 1
                    
                    with open(filename, 'w', encoding='utf-8') as file:
                        json.dump(data_final, file, ensure_ascii=False, indent=4)
                    
                    print(f"Saved: {filename}")
                    success = True
                    break  # Exit the URL loop if successful
                    
                except RequestException as e:
                    print(f"Failed to fetch from {url}: {e}")
                except json.JSONDecodeError:
                    print(f"Failed to decode JSON from {url}")
                    
            if not success:
                print(f"Failed to fetch data for barangay {barangay_code} after trying all URL patterns")
            
            # Add delay to prevent rate limiting
            time.sleep(1)
            
    except RequestException as e:
        print(f"Failed to fetch barangay data for region {code}: {e}")
        continue
    except json.JSONDecodeError:
        print(f"Failed to decode barangay JSON for region {code}")
        continue
# Out:
# Found 86 region codes
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532001.json
# Found 2 barangay codes for region 5532001
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320020.json
# Saved: data/abanon_55320020.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320021.json
# Saved: data/abanon_55320021.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532002.json
# Found 3 barangay codes for region 5532002
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320022.json
# Saved: data/agdao_55320022.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320023.json
# Saved: data/agdao_55320023.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320024.json
# Saved: data/agdao_55320024.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532003.json
# Found 1 barangay codes for region 5532003
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320025.json
# Saved: data/anando_55320025.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532004.json
# Found 2 barangay codes for region 5532004
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320026.json
# Saved: data/ano_55320026.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320027.json
# Saved: data/ano_55320027.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532005.json
# Found 2 barangay codes for region 5532005
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320028.json
# Saved: data/antipangol_55320028.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320029.json
# Saved: data/antipangol_55320029.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532006.json
# Found 2 barangay codes for region 5532006
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320030.json
# Saved: data/aponit_55320030.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320031.json
# Saved: data/aponit_55320031.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532007.json
# Found 4 barangay codes for region 5532007
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320032.json
# Saved: data/bacnar_55320032.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320033.json
# Saved: data/bacnar_55320033.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320034.json
# Saved: data/bacnar_55320034.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320035.json
# Saved: data/bacnar_55320035.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532008.json
# Found 2 barangay codes for region 5532008
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320036.json
# Saved: data/balaya_55320036.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320037.json
# Saved: data/balaya_55320037.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532009.json
# Found 2 barangay codes for region 5532009
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320038.json
# Saved: data/balayong_55320038.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320039.json
# Saved: data/balayong_55320039.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532010.json
# Found 2 barangay codes for region 5532010
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320040.json
# Saved: data/baldog_55320040.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320041.json
# Saved: data/baldog_55320041.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532011.json
# Found 3 barangay codes for region 5532011
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320042.json
# Saved: data/balite-sur_55320042.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320043.json
# Saved: data/balite-sur_55320043.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320044.json
# Saved: data/balite-sur_55320044.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532012.json
# Found 2 barangay codes for region 5532012
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320045.json
# Saved: data/balococ_55320045.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320046.json
# Saved: data/balococ_55320046.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532013.json
# Found 1 barangay codes for region 5532013
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320047.json
# Saved: data/bani_55320047.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532014.json
# Found 2 barangay codes for region 5532014
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320048.json
# Saved: data/bega_55320048.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320049.json
# Saved: data/bega_55320049.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532015.json
# Found 1 barangay codes for region 5532015
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320050.json
# Saved: data/bocboc_55320050.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532016.json
# Found 1 barangay codes for region 5532016
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320006.json
# Saved: data/bugallon-posadas-street_55320006.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532017.json
# Found 2 barangay codes for region 5532017
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320051.json
# Saved: data/bogaoan_55320051.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320052.json
# Saved: data/bogaoan_55320052.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532018.json
# Found 3 barangay codes for region 5532018
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320053.json
# Saved: data/bolingit_55320053.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320054.json
# Saved: data/bolingit_55320054.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320055.json
# Saved: data/bolingit_55320055.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532019.json
# Found 2 barangay codes for region 5532019
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320056.json
# Saved: data/bolosan_55320056.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320057.json
# Saved: data/bolosan_55320057.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532020.json
# Found 1 barangay codes for region 5532020
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320002.json
# Saved: data/bonifacio_55320002.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532021.json
# Found 2 barangay codes for region 5532021
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320058.json
# Saved: data/buenglat_55320058.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320059.json
# Saved: data/buenglat_55320059.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532022.json
# Found 1 barangay codes for region 5532022
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320005.json
# Saved: data/burgos-padlan_55320005.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532023.json
# Found 2 barangay codes for region 5532023
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320060.json
# Saved: data/cacaritan_55320060.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320061.json
# Saved: data/cacaritan_55320061.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532024.json
# Found 2 barangay codes for region 5532024
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320062.json
# Saved: data/caingal_55320062.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320063.json
# Saved: data/caingal_55320063.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532025.json
# Found 3 barangay codes for region 5532025
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320064.json
# Saved: data/calobaoan_55320064.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320065.json
# Saved: data/calobaoan_55320065.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320066.json
# Saved: data/calobaoan_55320066.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532026.json
# Found 3 barangay codes for region 5532026
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320067.json
# Saved: data/calomboyan_55320067.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320068.json
# Saved: data/calomboyan_55320068.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320069.json
# Saved: data/calomboyan_55320069.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532027.json
# Found 2 barangay codes for region 5532027
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320070.json
# Saved: data/capataan_55320070.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320071.json
# Saved: data/capataan_55320071.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532028.json
# Found 3 barangay codes for region 5532028
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320072.json
# Saved: data/caoayan-kiling_55320072.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320073.json
# Saved: data/caoayan-kiling_55320073.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320074.json
# Saved: data/caoayan-kiling_55320074.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532029.json
# Found 3 barangay codes for region 5532029
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320075.json
# Saved: data/cobol_55320075.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320076.json
# Saved: data/cobol_55320076.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320077.json
# Saved: data/cobol_55320077.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532030.json
# Found 4 barangay codes for region 5532030
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320078.json
# Saved: data/coliling_55320078.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320079.json
# Saved: data/coliling_55320079.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320080.json
# Saved: data/coliling_55320080.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320081.json
# Saved: data/coliling_55320081.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532031.json
# Found 2 barangay codes for region 5532031
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320082.json
# Saved: data/cruz_55320082.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320083.json
# Saved: data/cruz_55320083.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532032.json
# Found 2 barangay codes for region 5532032
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320084.json
# Saved: data/doyong_55320084.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320085.json
# Saved: data/doyong_55320085.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532035.json
# Found 2 barangay codes for region 5532035
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320086.json
# Saved: data/gamata_55320086.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320087.json
# Saved: data/gamata_55320087.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532036.json
# Found 3 barangay codes for region 5532036
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320088.json
# Saved: data/guelew_55320088.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320089.json
# Saved: data/guelew_55320089.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320090.json
# Saved: data/guelew_55320090.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532037.json
# Found 1 barangay codes for region 5532037
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320091.json
# Saved: data/ilang_55320091.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532038.json
# Found 2 barangay codes for region 5532038
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320092.json
# Saved: data/inerangan_55320092.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320093.json
# Saved: data/inerangan_55320093.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532039.json
# Found 2 barangay codes for region 5532039
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320094.json
# Saved: data/isla_55320094.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320095.json
# Saved: data/isla_55320095.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532040.json
# Found 3 barangay codes for region 5532040
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320096.json
# Saved: data/libas_55320096.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320097.json
# Saved: data/libas_55320097.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320098.json
# Saved: data/libas_55320098.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532041.json
# Found 2 barangay codes for region 5532041
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320099.json
# Saved: data/lilimasan_55320099.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320100.json
# Saved: data/lilimasan_55320100.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532043.json
# Found 1 barangay codes for region 5532043
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320101.json
# Saved: data/longos_55320101.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532044.json
# Found 1 barangay codes for region 5532044
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320007.json
# Saved: data/lucban_55320007.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532045.json
# Found 2 barangay codes for region 5532045
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320102.json
# Saved: data/mabalbalino_55320102.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320103.json
# Saved: data/mabalbalino_55320103.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532046.json
# Found 1 barangay codes for region 5532046
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320015.json
# Saved: data/mabini_55320015.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532047.json
# Found 2 barangay codes for region 5532047
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320104.json
# Saved: data/magtaking_55320104.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320105.json
# Saved: data/magtaking_55320105.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532048.json
# Found 3 barangay codes for region 5532048
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320106.json
# Saved: data/malacañang_55320106.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320107.json
# Saved: data/malacañang_55320107.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320108.json
# Saved: data/malacañang_55320108.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532050.json
# Found 1 barangay codes for region 5532050
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320109.json
# Saved: data/maliwara_55320109.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532051.json
# Found 2 barangay codes for region 5532051
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320110.json
# Saved: data/mamarlao_55320110.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320111.json
# Saved: data/mamarlao_55320111.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532052.json
# Found 2 barangay codes for region 5532052
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320112.json
# Saved: data/manzon_55320112.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320113.json
# Saved: data/manzon_55320113.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532053.json
# Found 3 barangay codes for region 5532053
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320114.json
# Saved: data/matagdem_55320114.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320115.json
# Saved: data/matagdem_55320115.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320116.json
# Saved: data/matagdem_55320116.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532054.json
# Found 2 barangay codes for region 5532054
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320117.json
# Saved: data/mestizo-norte_55320117.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320118.json
# Saved: data/mestizo-norte_55320118.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532055.json
# Found 2 barangay codes for region 5532055
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320119.json
# Saved: data/naguilayan_55320119.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320120.json
# Saved: data/naguilayan_55320120.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532056.json
# Found 2 barangay codes for region 5532056
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320121.json
# Saved: data/nilentap_55320121.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320122.json
# Saved: data/nilentap_55320122.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532057.json
# Found 2 barangay codes for region 5532057
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320018.json
# Saved: data/padilla-gomez_55320018.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320019.json
# Saved: data/padilla-gomez_55320019.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532058.json
# Found 3 barangay codes for region 5532058
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320123.json
# Saved: data/pagal_55320123.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320124.json
# Saved: data/pagal_55320124.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320125.json
# Saved: data/pagal_55320125.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532060.json
# Found 2 barangay codes for region 5532060
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320128.json
# Saved: data/palaming_55320128.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320129.json
# Saved: data/palaming_55320129.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532061.json
# Found 1 barangay codes for region 5532061
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320001.json
# Saved: data/palaris_55320001.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532062.json
# Found 1 barangay codes for region 5532062
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320130.json
# Saved: data/palospos_55320130.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532063.json
# Found 3 barangay codes for region 5532063
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320131.json
# Saved: data/pangalangan_55320131.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320132.json
# Saved: data/pangalangan_55320132.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320133.json
# Saved: data/pangalangan_55320133.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532064.json
# Found 2 barangay codes for region 5532064
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320134.json
# Saved: data/pangoloan_55320134.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320135.json
# Saved: data/pangoloan_55320135.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532065.json
# Found 3 barangay codes for region 5532065
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320136.json
# Saved: data/pangpang_55320136.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320137.json
# Saved: data/pangpang_55320137.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320138.json
# Saved: data/pangpang_55320138.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532066.json
# Found 2 barangay codes for region 5532066
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320126.json
# Saved: data/paitan-panoypoy_55320126.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320127.json
# Saved: data/paitan-panoypoy_55320127.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532067.json
# Found 1 barangay codes for region 5532067
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320139.json
# Saved: data/parayao_55320139.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532069.json
# Found 2 barangay codes for region 5532069
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320140.json
# Saved: data/payapa_55320140.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320141.json
# Saved: data/payapa_55320141.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532070.json
# Found 2 barangay codes for region 5532070
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320142.json
# Saved: data/payar_55320142.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320143.json
# Saved: data/payar_55320143.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532071.json
# Found 1 barangay codes for region 5532071
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320016.json
# Saved: data/perez-boulevard_55320016.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532072.json
# Found 2 barangay codes for region 5532072
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320144.json
# Saved: data/polo_55320144.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320145.json
# Saved: data/polo_55320145.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532073.json
# Found 2 barangay codes for region 5532073
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320013.json
# Saved: data/quezon-boulevard_55320013.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320014.json
# Saved: data/quezon-boulevard_55320014.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532074.json
# Found 3 barangay codes for region 5532074
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320146.json
# Saved: data/quintong_55320146.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320147.json
# Saved: data/quintong_55320147.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320148.json
# Saved: data/quintong_55320148.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532075.json
# Found 2 barangay codes for region 5532075
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320009.json
# Saved: data/rizal_55320009.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320010.json
# Saved: data/rizal_55320010.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532076.json
# Found 1 barangay codes for region 5532076
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320008.json
# Saved: data/roxas-boulevard_55320008.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532077.json
# Found 2 barangay codes for region 5532077
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320149.json
# Saved: data/salinap_55320149.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320150.json
# Saved: data/salinap_55320150.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532078.json
# Found 3 barangay codes for region 5532078
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320151.json
# Saved: data/san-juan_55320151.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320152.json
# Saved: data/san-juan_55320152.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320153.json
# Saved: data/san-juan_55320153.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532079.json
# Found 2 barangay codes for region 5532079
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320003.json
# Saved: data/san-pedro-taloy_55320003.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320004.json
# Saved: data/san-pedro-taloy_55320004.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532080.json
# Found 2 barangay codes for region 5532080
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320154.json
# Saved: data/sapinit_55320154.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320155.json
# Saved: data/sapinit_55320155.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532081.json
# Found 1 barangay codes for region 5532081
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320012.json
# Saved: data/pnr-station-site_55320012.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532082.json
# Found 1 barangay codes for region 5532082
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320156.json
# Saved: data/supo_55320156.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532083.json
# Found 2 barangay codes for region 5532083
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320157.json
# Saved: data/talang_55320157.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320158.json
# Saved: data/talang_55320158.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532084.json
# Found 2 barangay codes for region 5532084
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320159.json
# Saved: data/tamayo_55320159.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320160.json
# Saved: data/tamayo_55320160.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532085.json
# Found 3 barangay codes for region 5532085
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320161.json
# Saved: data/tandoc_55320161.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320162.json
# Saved: data/tandoc_55320162.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320163.json
# Saved: data/tandoc_55320163.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532086.json
# Found 3 barangay codes for region 5532086
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320164.json
# Saved: data/tarece_55320164.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320165.json
# Saved: data/tarece_55320165.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320166.json
# Saved: data/tarece_55320166.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532087.json
# Found 2 barangay codes for region 5532087
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320167.json
# Saved: data/tarectec_55320167.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320168.json
# Saved: data/tarectec_55320168.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532088.json
# Found 1 barangay codes for region 5532088
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320169.json
# Saved: data/tayambani_55320169.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532089.json
# Found 1 barangay codes for region 5532089
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320170.json
# Saved: data/tebag_55320170.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532090.json
# Found 4 barangay codes for region 5532090
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320171.json
# Saved: data/turac_55320171.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320172.json
# Saved: data/turac_55320172.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320173.json
# Saved: data/turac_55320173.json
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320174.json
# Saved: data/turac_55320174.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532091.json
# Found 1 barangay codes for region 5532091
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320017.json
# Saved: data/m.-soriano_55320017.json
# Fetching barangay data from: https://2025electionresults.comelec.gov.ph/data/regions/precinct/55/5532092.json
# Found 1 barangay codes for region 5532092
# Trying: https://2025electionresults.comelec.gov.ph/data/er/553/55320011.json
# Saved: data/tandang-sora_55320011.json

# %%
def aggregate_barangay_data(data_folder):
    """
    Load and aggregate barangay JSON files with naming format <barangay>_<numeric code>.json
    """
    # Dictionary to hold aggregated data by barangay and candidate
    aggregated_votes = defaultdict(int)
    barangay_info = {}
    
    # Get all JSON files in the data folder
    json_files = [f for f in os.listdir(data_folder) if f.endswith('.json')]
    
    for file_name in json_files:
        file_path = os.path.join(data_folder, file_name)
        
        # Extract barangay name using a regular expression to handle numeric codes
        # This will match filenames like "abanon_55320020.json"
        match = re.match(r'^(.+?)_\d+\.json$', file_name)
        if match:
            base_barangay = match.group(1)
        else:
            # Fallback: just remove the .json extension
            base_barangay = file_name.replace('.json', '')
        
        # Read JSON data
        with open(file_path, 'r') as file:
            data = json.load(file)
        
        # The rest of the function remains the same
        # Store barangay information
        if base_barangay not in barangay_info:
            barangay_info[base_barangay] = {
                'location': data['information']['location'],
                'precinct_id': data['information']['precinctId'],
                'registered_voters': data['information']['numberOfRegisteredVoters'],
                'actual_voters': data['information']['numberOfActuallyVoters'],
                'turnout': data['information']['turnout']
            }
        
        # Process national contests
        for contest in data['national']:
            contest_name = contest['contestName']
            
            for candidate in contest['candidates']['candidates']:
                key = (base_barangay, 'National', contest_name, candidate['name'])
                aggregated_votes[key] += candidate['votes']
        
        # Process local contests
        for contest in data['local']:
            contest_name = contest['contestName']
            
            for candidate in contest['candidates']['candidates']:
                key = (base_barangay, 'Local', contest_name, candidate['name'])
                aggregated_votes[key] += candidate['votes']
    
    # Convert aggregated data to DataFrame format
    results = []
    for (barangay, contest_type, contest_name, candidate_name), votes in aggregated_votes.items():
        results.append({
            'barangay': barangay,
            'location': barangay_info[barangay]['location'],
            'precinct_id': barangay_info[barangay]['precinct_id'],
            'registered_voters': barangay_info[barangay]['registered_voters'],
            'actual_voters': barangay_info[barangay]['actual_voters'],
            'turnout': barangay_info[barangay]['turnout'],
            'contest_type': contest_type,
            'contest_name': contest_name,
            'candidate_name': candidate_name,
            'votes': votes
        })
    
    df = pd.DataFrame(results)
    
    # Calculate percentage for each candidate within their contest and barangay
    contest_total_votes = df.groupby(['barangay', 'contest_type', 'contest_name'])['votes'].transform('sum')
    df['percentage'] = (df['votes'] / contest_total_votes) * 100
    df['percentage'] = df['percentage'].round(2)
    
    return df

def main():
    # Replace with your data folder path
    data_folder = "data"
    
    # Aggregate barangay data
    df = aggregate_barangay_data(data_folder)
    
    # Display basic information
    print(f"Total candidates across all barangays: {len(df)}")
    print(f"Unique barangays: {df['barangay'].nunique()}")
    
    # Top candidates per contest (aggregated across all barangays)
    print("\nTop 5 candidates for Senator position:")
    senator_results = df[df['contest_name'] == 'SENATOR of PHILIPPINES']
    top_senators = senator_results.groupby('candidate_name')['votes'].sum().reset_index()
    top_senators = top_senators.sort_values('votes', ascending=False).head(5)
    print(top_senators)
    
    # Party List results
    print("\nTop 5 Party List results:")
    party_results = df[df['contest_name'] == 'PARTY LIST of PHILIPPINES']
    top_parties = party_results.groupby('candidate_name')['votes'].sum().reset_index()
    top_parties = top_parties.sort_values('votes', ascending=False).head(5)
    print(top_parties)
    
    # Save to CSV
    df.to_csv('aggregated_election_results.csv', index=False)
    print("\nAggregated data saved to 'aggregated_election_results.csv'")

if __name__ == "__main__":
    main()
# Out:
# Total candidates across all barangays: 22360
# Unique barangays: 86
#
# Top 5 candidates for Senator position:
#               candidate_name  votes
# 44      5. AQUINO, BAM (KNP)  51346
# 54     59. SOTTO, TITO (NPC)  45514
# 59  63. TULFO, ERWIN (LAKAS)  44365
# 0    1. ABALOS, BENHUR (PFP)  41272
# 9     18. CAYETANO, PIA (NP)  40018
#
# Top 5 Party List results:
#              candidate_name  votes
# 79   3 FPJ PANDAY BAYANIHAN  17145
# 13                110 ABONO   9493
# 26        122 PINOY WORKERS   6406
# 6     104 SOLID NORTH PARTY   5479
# 103              51 AKBAYAN   5337
#
# Aggregated data saved to 'aggregated_election_results.csv'

# %%
def create_contest_datasets(data_folder):
    """
    Create separate datasets for each contest with:
    - Candidates in rows (left side)
    - Barangays in columns (headers)
    - Vote counts in cells (aggregated across multiple files for the same barangay)
    
    Returns a tuple of (contest_datasets, all_barangays)
    """
    # Dictionary to store votes by contest, candidate, and barangay
    contest_data = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
    
    # List to track all barangays and contests we encounter
    all_barangays = set()
    all_contests = set()
    
    # Get all JSON files in the data folder
    json_files = [f for f in os.listdir(data_folder) if f.endswith('.json')]
    
    # Process each file
    for file_name in json_files:
        file_path = os.path.join(data_folder, file_name)
        
        # Extract base barangay name (remove _2, _3 suffixes if present)
        base_barangay = re.sub(r'_\d+\.json$', '', file_name)
        base_barangay = base_barangay.replace('.json', '')
        all_barangays.add(base_barangay)
        
        # Read JSON data
        with open(file_path, 'r') as file:
            data = json.load(file)
        
        # Process national contests
        for contest in data['national']:
            contest_name = contest['contestName']
            all_contests.add(contest_name)
            
            # Process each candidate
            for candidate in contest['candidates']['candidates']:
                # Add votes for this candidate in this barangay
                # Using defaultdict(int) ensures we're adding to the existing count
                contest_data[contest_name][candidate['name']][base_barangay] += candidate['votes']
        
        # Process local contests
        for contest in data['local']:
            contest_name = contest['contestName']
            all_contests.add(contest_name)
            
            # Process each candidate
            for candidate in contest['candidates']['candidates']:
                # Add votes for this candidate in this barangay
                contest_data[contest_name][candidate['name']][base_barangay] += candidate['votes']
    
    # Convert to DataFrames
    dataframes = {}
    all_barangays_list = sorted(list(all_barangays))
    
    for contest_name in all_contests:
        # Create a list of dictionaries (one per candidate)
        rows = []
        for candidate_name, barangay_votes in contest_data[contest_name].items():
            # Start with the candidate name
            row = {'Candidate': candidate_name}
            
            # Add votes for each barangay
            for barangay in all_barangays_list:
                row[barangay] = barangay_votes.get(barangay, 0)
            
            # Add a total column
            row['Total'] = sum(barangay_votes.values())
            
            rows.append(row)
        
        # Create DataFrame and sort by total votes
        df = pd.DataFrame(rows)
        if not df.empty:
            df = df.sort_values('Total', ascending=False)
            
            # Move Candidate column to the front
            candidate_col = df.pop('Candidate')
            df.insert(0, 'Candidate', candidate_col)
        
        # Store in our dictionary of dataframes
        dataframes[contest_name] = df
    
    # Return both the dataframes and the list of barangays
    return dataframes, all_barangays_list

def main():
    # Replace with your data folder path
    data_folder = "data"
    
    # Create results folder if it doesn't exist
    results_folder = "./results-per-position"
    if not os.path.exists(results_folder):
        os.makedirs(results_folder)
        print(f"Created directory: {results_folder}")
    
    # Create contest datasets and get the list of barangays
    contest_datasets, all_barangays = create_contest_datasets(data_folder)
    
    # Display summary
    print(f"Created {len(contest_datasets)} contest datasets\n")
    
    # Display each dataset (or just the first few rows)
    for contest_name, df in contest_datasets.items():
        print(f"Dataset: {contest_name}")
        print(f"Shape: {df.shape[0]} candidates × {df.shape[1]} columns")
        print(df.head(5))  # Show top 5 candidates
        print("\n" + "="*50 + "\n")
        
        # Save to CSV in the results folder
        clean_name = re.sub(r'[^\w\s]', '', contest_name).replace(' ', '_')
        filename = os.path.join(results_folder, f"{clean_name}_results.csv")
        df.to_csv(filename, index=False)
        print(f"Saved to {filename}")
        print("\n")

    # Create a summary DataFrame of total votes per barangay
    barangay_summary = pd.DataFrame(index=all_barangays)
    for contest_name, df in contest_datasets.items():
        if 'Total' in df.columns:
            # Save the contest totals without the 'Candidate' column
            contest_cols = [col for col in df.columns if col not in ['Candidate', 'Total']]
            contest_totals = df[contest_cols].sum()
            barangay_summary[contest_name] = contest_totals
    
    # Add total votes column
    barangay_summary['Total Votes'] = barangay_summary.sum(axis=1)
    
    # Save summary to the results folder
    summary_filename = os.path.join(results_folder, 'barangay_vote_summary.csv')
    barangay_summary.to_csv(summary_filename)
    print(f"Saved barangay summary to '{summary_filename}'")

if __name__ == "__main__":
    main()
# Out:
# Created directory: ./results-per-position
# Created 9 contest datasets
#
# Dataset: PROVINCIAL VICE-GOVERNOR of PANGASINAN
# Shape: 2 candidates × 88 columns
#                   Candidate  abanon  agdao  anando  ano  antipangol  aponit  \
# 0  1. LAMBINO, MARK (LAKAS)     742   1292     360  960         593     791
# 1      2. NACAR, NOEL (API)     201    462      95  351         267     204
#
#    bacnar  balaya  balayong  ...  talang  tamayo  tandang-sora  tandoc  \
# 0    1780     684       696  ...     669     910           251    1150
# 1     602     229       213  ...     160     337            88     406
#
#    tarece  tarectec  tayambani  tebag  turac  Total
# 0    1468       637        483    455   1861  67244
# 1     411       163        136    183    665  22345
#
# [2 rows x 88 columns]
#
# ==================================================
#
# Saved to ./results-per-position/PROVINCIAL_VICEGOVERNOR_of_PANGASINAN_results.csv
#
#
# Dataset: VICE-MAYOR of PANGASINAN - CITY OF SAN CARLOS
# Shape: 2 candidates × 88 columns
#                    Candidate  abanon  agdao  anando  ano  antipangol  aponit  \
# 1     2. RESUELLO, BOGS (NP)     602   1022     281  627         668     738
# 0  1. LOMBOY, JONATHAN (NPC)     497    974     284  901         341     485
#
#    bacnar  balaya  balayong  ...  talang  tamayo  tandang-sora  tandoc  \
# 1    1605     744       748  ...     531     846           214    1165
# 0    1130     335       338  ...     440     750           163     682
#
#    tarece  tarectec  tayambani  tebag  turac  Total
# 1    1295       571        344    480   1815  59903
# 0     925       348        440    290   1171  45881
#
# [2 rows x 88 columns]
#
# ==================================================
#
# Saved to ./results-per-position/VICEMAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_results.csv
#
#
# Dataset: SENATOR of PHILIPPINES
# Shape: 66 candidates × 88 columns
#                    Candidate  abanon  agdao  anando  ano  antipangol  aponit  \
# 4       5. AQUINO, BAM (KNP)     564   1026     234  711         400     505
# 58     59. SOTTO, TITO (NPC)     441    893     226  596         434     487
# 62  63. TULFO, ERWIN (LAKAS)     449    790     243  687         455     469
# 0    1. ABALOS, BENHUR (PFP)     446    804     214  569         354     479
# 17    18. CAYETANO, PIA (NP)     402    781     213  581         392     414
#
#     bacnar  balaya  balayong  ...  talang  tamayo  tandang-sora  tandoc  \
# 4     1393     459       521  ...     496     586           200     892
# 58    1271     441       475  ...     418     672           171     794
# 62    1259     428       455  ...     421     678           138     811
# 0     1056     385       408  ...     415     609           147     825
# 17    1105     374       437  ...     397     537           140     617
#
#     tarece  tarectec  tayambani  tebag  turac  Total
# 4     1261       470        311    394   1495  51346
# 58     942       374        281    340   1345  45514
# 62     874       352        308    300   1258  44365
# 0      907       368        279    318   1261  41272
# 17     881       348        246    266   1123  40018
#
# [5 rows x 88 columns]
#
# ==================================================
#
# Saved to ./results-per-position/SENATOR_of_PHILIPPINES_results.csv
#
#
# Dataset: MEMBER, SANGGUNIANG PANLUNGSOD of PANGASINAN - CITY OF SAN CARLOS - LONE DIST
# Shape: 23 candidates × 88 columns
#                      Candidate  abanon  agdao  anando  ano  antipangol  \
# 3        4. BANIQUED, SAM (NP)     657    957     278  857         617
# 8         9. FERMIN, BIDO (NP)     439   1032     189  651         539
# 7     8. CANO, KUYA NICK (NPC)     559   1142     369  646         493
# 6   7. CANCINO, CHRISTIAN (NP)     349    918     345  720         558
# 10      11. GARCIA, MANOY (NP)     472    943     232  621         650
#
#     aponit  bacnar  balaya  balayong  ...  talang  tamayo  tandang-sora  \
# 3      592    1624     628       598  ...     424     761           178
# 8      513    1452     551       623  ...     376     672           213
# 7      545    1485     466       522  ...     361     852           175
# 6      709    1113     663       665  ...     669     745           198
# 10     869    1316     573       453  ...     681     959           168
#
#     tandoc  tarece  tarectec  tayambani  tebag  turac  Total
# 3      876    1106       478        345    435   2029  54049
# 8      999    1097       390        263    358   1279  50954
# 7      940    1047       467        395    350   1164  50218
# 6      920    1025       322        390    311    808  49862
# 10     629    1061       347        350    309   1099  49664
#
# [5 rows x 88 columns]
#
# ==================================================
#
# Saved to ./results-per-position/MEMBER_SANGGUNIANG_PANLUNGSOD_of_PANGASINAN__CITY_OF_SAN_CARLOS__LONE_DIST_results.csv
#
#
# Dataset: MEMBER, SANGGUNIANG PANLALAWIGAN of PANGASINAN - THIRD PROVDIST
# Shape: 5 candidates × 88 columns
#                         Candidate  abanon  agdao  anando   ano  antipangol  \
# 0   1. BANIQUED, DRA. SHIELA (NP)     839   1356     418  1107         771
# 4        5. VENTANILLA, VICI (NP)     759   1150     357   713         523
# 3  4. TULAGAN, GENEROSO JR. (NPC)     147    461      46   240         110
# 1   2. BAUZON, JOSEPH ARMAN (API)      60    299      53   477         273
# 2      3. GONZALES, EDUARDO (IND)      31     51      11    52          25
#
#    aponit  bacnar  balaya  balayong  ...  talang  tamayo  tandang-sora  \
# 0     830    1925     697       768  ...     640    1070           244
# 4     683    1789     761       608  ...     562     960           231
# 3     190     530     134       182  ...     246     205            84
# 1     174     359     121       234  ...     186     190            78
# 2      36      61      32        24  ...      25      44             6
#
#    tandoc  tarece  tarectec  tayambani  tebag  turac  Total
# 0    1199    1565       698        416    543   2178  73498
# 4    1092    1219       555        356    354   1752  61853
# 3     274     539       177        310    138    485  20479
# 1     432     333       136        126    223    502  16525
# 2      47      45        10         23     21     72   2751
#
# [5 rows x 88 columns]
#
# ==================================================
#
# Saved to ./results-per-position/MEMBER_SANGGUNIANG_PANLALAWIGAN_of_PANGASINAN__THIRD_PROVDIST_results.csv
#
#
# Dataset: PROVINCIAL GOVERNOR of PANGASINAN
# Shape: 2 candidates × 88 columns
#                     Candidate  abanon  agdao  anando   ano  antipangol  \
# 0  1. ESPINO, AMADO III (API)     545   1146     277  1075         569
# 1    2. GUICO, RAMON III (NP)     552    832     272   453         434
#
#    aponit  bacnar  balaya  balayong  ...  talang  tamayo  tandang-sora  \
# 0     658    1594     645       671  ...     466     956           216
# 1     560    1128     413       403  ...     492     605           158
#
#    tandoc  tarece  tarectec  tayambani  tebag  turac  Total
# 0    1132    1325       582        413    500   1845  62580
# 1     713     874       324        363    265   1115  42277
#
# [2 rows x 88 columns]
#
# ==================================================
#
# Saved to ./results-per-position/PROVINCIAL_GOVERNOR_of_PANGASINAN_results.csv
#
#
# Dataset: PARTY LIST of PHILIPPINES
# Shape: 155 candidates × 88 columns
#                   Candidate  abanon  agdao  anando  ano  antipangol  aponit  \
# 2    3 FPJ PANDAY BAYANIHAN     182    228     105  171         162     197
# 108               110 ABONO     139    432      84   37         176     241
# 120       122 PINOY WORKERS     139     39      13   23          14      73
# 102   104 SOLID NORTH PARTY      75     44      85   76          30      46
# 50               51 AKBAYAN      43    102      12   74          23      39
#
#      bacnar  balaya  balayong  ...  talang  tamayo  tandang-sora  tandoc  \
# 2       408     209       179  ...     131     202           116     405
# 108     136      54        17  ...     127     312            14      47
# 120     165     121       122  ...     134      23            29      84
# 102      62      15        50  ...      45      10             6      65
# 50      110      42        57  ...      49      46            28      98
#
#      tarece  tarectec  tayambani  tebag  turac  Total
# 2       223       165        174    129    208  17145
# 108     436        30        161    127    504   9493
# 120      25        53         41     16    139   6406
# 102      20        80          4     51    220   5479
# 50      162        58         34     36    153   5337
#
# [5 rows x 88 columns]
#
# ==================================================
#
# Saved to ./results-per-position/PARTY_LIST_of_PHILIPPINES_results.csv
#
#
# Dataset: MAYOR of PANGASINAN - CITY OF SAN CARLOS
# Shape: 2 candidates × 88 columns
#                   Candidate  abanon  agdao  anando  ano  antipangol  aponit  \
# 0    1. RESUELLO, AYOY (NP)     581   1034     365  604         665     732
# 1  2. SORIANO, LESTER (NPC)     534    978     210  946         357     524
#
#    bacnar  balaya  balayong  ...  talang  tamayo  tandang-sora  tandoc  \
# 0    1622     695       681  ...     498     896           208    1096
# 1    1131     388       413  ...     475     728           169     774
#
#    tarece  tarectec  tayambani  tebag  turac  Total
# 0    1130       546        373    479   1588  58261
# 1    1106       374        432    300   1439  48758
#
# [2 rows x 88 columns]
#
# ==================================================
#
# Saved to ./results-per-position/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_results.csv
#
#
# Dataset: MEMBER, HOUSE OF REPRESENTATIVES of PANGASINAN - THIRD LEGDIST
# Shape: 3 candidates × 88 columns
#                         Candidate  abanon  agdao  anando   ano  antipangol  \
# 1  2. ARENAS, RACHEL BABY (LAKAS)    1024   1689     513  1404         913
# 2         3. TULAGAN, GENER (IND)      38    163      17    64          41
# 0        1. ABSOLOR, GEORGE (IND)       9     52      11    20          12
#
#    aponit  bacnar  balaya  balayong  ...  talang  tamayo  tandang-sora  \
# 1    1056    2470     982       971  ...     827    1331           331
# 2      79     148      29        65  ...      98     101            27
# 0      20      30      14         8  ...      13      39             5
#
#    tandoc  tarece  tarectec  tayambani  tebag  turac  Total
# 1    1650    1904       808        547    681   2677  91987
# 2      99     195        57        200     58    145   7495
# 0      27      36        12         16     10     40   1877
#
# [3 rows x 88 columns]
#
# ==================================================
#
# Saved to ./results-per-position/MEMBER_HOUSE_OF_REPRESENTATIVES_of_PANGASINAN__THIRD_LEGDIST_results.csv
#
#
# Saved barangay summary to './results-per-position/barangay_vote_summary.csv'

# %%
def create_mayor_graphs(results_folder="./results-per-position"):
    """
    Create line and bar graphs showing mayoral votes per barangay
    """
    # Use the exact filename from the screenshot
    mayor_file = os.path.join(results_folder, "MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_results.csv")
    
    # Check if the file exists
    if not os.path.exists(mayor_file):
        print(f"Error: File does not exist: {mayor_file}")
        # List all files in the directory to debug
        print("Files in the directory:")
        for file in os.listdir(results_folder):
            print(f"  - {file}")
        return
    
    print(f"Found mayor file: {mayor_file}")
    contest_name = "MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS"
    
    # Load the mayor data
    mayor_df = pd.read_csv(mayor_file)
    
    # Get the candidate and barangay columns
    candidates = mayor_df['Candidate'].tolist()
    
    # Simplify candidate names for better display (just get the name part)
    simplified_names = []
    for name in candidates:
        # Extract the name part between the number and the parenthesis
        match = re.search(r'\d+\.\s+(.*?)\s+\(', name)
        if match:
            simplified_names.append(match.group(1))
        else:
            simplified_names.append(name)
    
    # Get barangay columns (exclude 'Candidate' and 'Total')
    barangays = [col for col in mayor_df.columns if col not in ['Candidate', 'Total']]
    
    # Transpose the data for plotting (exclude 'Candidate' and 'Total' columns)
    plot_data = mayor_df[barangays].copy()
    plot_data.index = simplified_names
    
    # Create directory for graphs if it doesn't exist
    graphs_folder = os.path.join(results_folder, 'graphs')
    if not os.path.exists(graphs_folder):
        os.makedirs(graphs_folder)
        print(f"Created directory: {graphs_folder}")
    
    # Generate a clean name for filenames
    clean_contest = re.sub(r'[^\w\s]', '', contest_name).replace(' ', '_')
    
    # ========== LINE GRAPH ==========
    plt.figure(figsize=(14, 8))
    
    # Plot each candidate as a line
    for i, candidate in enumerate(simplified_names):
        plt.plot(barangays, plot_data.loc[candidate], marker='o', linewidth=2, 
                 label=candidate, markersize=8)
    
    # Add labels and title
    plt.title('Mayoral Votes per Barangay (Line Graph)', fontsize=16)
    plt.xlabel('Barangay', fontsize=14)
    plt.ylabel('Number of Votes', fontsize=14)
    plt.xticks(rotation=45, ha='right', fontsize=12)
    plt.legend(title='Candidates', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    
    # Adjust layout and save
    plt.tight_layout()
    line_graph_path = os.path.join(graphs_folder, f'{clean_contest}_line_graph.png')
    plt.savefig(line_graph_path, dpi=300)
    plt.close()
    print(f"Saved line graph to: {line_graph_path}")
    
    # ========== BAR GRAPH ==========
    plt.figure(figsize=(14, 8))
    
    # Set the positions for the bars
    bar_width = 0.8 / len(candidates)
    positions = np.arange(len(barangays))
    
    # Plot each candidate as a group of bars
    for i, candidate in enumerate(simplified_names):
        offset = i * bar_width - (len(candidates) * bar_width / 2) + (bar_width / 2)
        bars = plt.bar(positions + offset, plot_data.loc[candidate], 
                        width=bar_width, label=candidate)
    
    # Add labels and title
    plt.title('Mayoral Votes per Barangay (Bar Graph)', fontsize=16)
    plt.xlabel('Barangay', fontsize=14)
    plt.ylabel('Number of Votes', fontsize=14)
    plt.xticks(positions, barangays, rotation=45, ha='right', fontsize=12)
    plt.legend(title='Candidates', fontsize=12)
    plt.grid(True, axis='y', linestyle='--', alpha=0.7)
    
    # Adjust layout and save
    plt.tight_layout()
    bar_graph_path = os.path.join(graphs_folder, f'{clean_contest}_bar_graph.png')
    plt.savefig(bar_graph_path, dpi=300)
    plt.close()
    print(f"Saved bar graph to: {bar_graph_path}")
    
    # ========== GROUPED BAR GRAPH (Alternative View) ==========
    plt.figure(figsize=(14, 8))
    
    # Transpose for grouped bar chart
    stacked_data = plot_data.T
    
    # Create grouped bar chart
    stacked_data.plot(kind='bar', stacked=False, figsize=(14, 8))
    
    # Add labels and title
    plt.title('Mayoral Votes per Barangay (Grouped Bar Graph)', fontsize=16)
    plt.xlabel('Barangay', fontsize=14)
    plt.ylabel('Number of Votes', fontsize=14)
    plt.xticks(rotation=45, ha='right', fontsize=12)
    plt.legend(title='Candidates', fontsize=12)
    plt.grid(True, axis='y', linestyle='--', alpha=0.7)
    
    # Adjust layout and save
    plt.tight_layout()
    grouped_bar_path = os.path.join(graphs_folder, f'{clean_contest}_grouped_bar_graph.png')
    plt.savefig(grouped_bar_path, dpi=300)
    plt.close()
    print(f"Saved grouped bar graph to: {grouped_bar_path}")

# Create the graphs
create_mayor_graphs("./results-per-position")
# Out:
# Found mayor file: ./results-per-position/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_results.csv
# Created directory: ./results-per-position/graphs
# Saved line graph to: ./results-per-position/graphs/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_line_graph.png
# Saved bar graph to: ./results-per-position/graphs/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_bar_graph.png
# Saved grouped bar graph to: ./results-per-position/graphs/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_grouped_bar_graph.png

# %%
def create_improved_mayor_graphs(results_folder="./results-per-position"):
    """
    Create improved visualizations for mayoral votes with better handling of many barangays
    """
    
    # Use the exact filename from the original code
    mayor_file = os.path.join(results_folder, "MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_results.csv")
    
    # Check if the file exists
    if not os.path.exists(mayor_file):
        print(f"Error: File does not exist: {mayor_file}")
        # List all files in the directory to debug
        print("Files in the directory:")
        for file in os.listdir(results_folder):
            print(f"  - {file}")
        return
    
    print(f"Found mayor file: {mayor_file}")
    contest_name = "MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS"
    
    # Load the mayor data
    mayor_df = pd.read_csv(mayor_file)
    
    # Get the candidate and barangay columns
    candidates = mayor_df['Candidate'].tolist()
    
    # Simplify candidate names for better display
    simplified_names = []
    for name in candidates:
        # Extract the name part between the number and the parenthesis
        match = re.search(r'\d+\.\s+(.*?)\s+\(', name)
        if match:
            simplified_names.append(match.group(1))
        else:
            simplified_names.append(name)
    
    # Get barangay columns (exclude 'Candidate' and 'Total')
    barangays = [col for col in mayor_df.columns if col not in ['Candidate', 'Total']]
    
    # Transpose the data for plotting
    plot_data = mayor_df[barangays].copy()
    plot_data.index = simplified_names
    
    # Create directory for graphs in the root directory
    graphs_folder = "./mayor_visualizations"
    if not os.path.exists(graphs_folder):
        os.makedirs(graphs_folder)
        print(f"Created directory: {graphs_folder}")
    
    # Generate a clean name for filenames
    clean_contest = re.sub(r'[^\w\s]', '', contest_name).replace(' ', '_')
    
    # ========== SOLUTION 1: SPLIT INTO MULTIPLE GRAPHS ==========
    # Define how many barangays per graph
    barangays_per_graph = 15
    
    # Calculate how many graphs we need
    num_graphs = len(barangays) // barangays_per_graph
    if len(barangays) % barangays_per_graph > 0:
        num_graphs += 1
    
    # Create a line graph for each group of barangays
    for graph_num in range(num_graphs):
        start_idx = graph_num * barangays_per_graph
        end_idx = min(start_idx + barangays_per_graph, len(barangays))
        
        current_barangays = barangays[start_idx:end_idx]
        
        plt.figure(figsize=(14, 8))
        
        # Plot each candidate as a line
        for i, candidate in enumerate(simplified_names):
            plt.plot(current_barangays, plot_data.loc[candidate, current_barangays], 
                     marker='o', linewidth=2, label=candidate, markersize=8)
        
        # Add labels and title
        plt.title(f'Mayoral Votes per Barangay - Group {graph_num+1} (Line Graph)', fontsize=16)
        plt.xlabel('Barangay', fontsize=14)
        plt.ylabel('Number of Votes', fontsize=14)
        plt.xticks(rotation=45, ha='right', fontsize=12)
        plt.legend(title='Candidates', fontsize=12)
        plt.grid(True, linestyle='--', alpha=0.7)
        
        # Adjust layout and save
        plt.tight_layout()
        split_line_path = os.path.join(graphs_folder, f'{clean_contest}_line_graph_group_{graph_num+1}.png')
        plt.savefig(split_line_path, dpi=300)
        plt.close()
        print(f"Saved split line graph {graph_num+1} to: {split_line_path}")
    
    # ========== SOLUTION 2: HEATMAP VISUALIZATION ==========
    plt.figure(figsize=(16, 10))
    
    # Normalize the data for color mapping
    norm = Normalize(vmin=plot_data.values.min(), vmax=plot_data.values.max())
    
    # Plot the heatmap
    plt.imshow(plot_data, aspect='auto', cmap='viridis', norm=norm)
    
    # Add labels and title
    plt.title('Mayoral Votes per Barangay (Heatmap)', fontsize=16)
    plt.xlabel('Barangay', fontsize=14)
    plt.ylabel('Candidate', fontsize=14)
    
    # Add x and y ticks
    plt.xticks(np.arange(len(barangays)), barangays, rotation=90, fontsize=8)
    plt.yticks(np.arange(len(simplified_names)), simplified_names, fontsize=12)
    
    # Add a colorbar
    cbar = plt.colorbar()
    cbar.set_label('Number of Votes', fontsize=14)
    
    # Adjust layout and save
    plt.tight_layout()
    heatmap_path = os.path.join(graphs_folder, f'{clean_contest}_heatmap.png')
    plt.savefig(heatmap_path, dpi=300, bbox_inches='tight')
    plt.close()
    print(f"Saved heatmap to: {heatmap_path}")
    
    # ========== SOLUTION 3: TOP BARANGAYS BAR CHART ==========
    # Calculate total votes per barangay
    barangay_totals = plot_data.sum()
    
    # Get the top 15 barangays by total votes
    top_barangays = barangay_totals.nlargest(15).index.tolist()
    
    plt.figure(figsize=(14, 8))
    
    # Set the positions for the bars
    bar_width = 0.8 / len(simplified_names)
    positions = np.arange(len(top_barangays))
    
    # Plot each candidate as a group of bars, but only for top barangays
    for i, candidate in enumerate(simplified_names):
        offset = i * bar_width - (len(simplified_names) * bar_width / 2) + (bar_width / 2)
        plt.bar(positions + offset, plot_data.loc[candidate, top_barangays], 
                width=bar_width, label=candidate)
    
    # Add labels and title
    plt.title('Mayoral Votes for Top 15 Barangays by Total Votes', fontsize=16)
    plt.xlabel('Barangay', fontsize=14)
    plt.ylabel('Number of Votes', fontsize=14)
    plt.xticks(positions, top_barangays, rotation=45, ha='right', fontsize=12)
    plt.legend(title='Candidates', fontsize=12)
    plt.grid(True, axis='y', linestyle='--', alpha=0.7)
    
    # Adjust layout and save
    plt.tight_layout()
    top_barangays_path = os.path.join(graphs_folder, f'{clean_contest}_top_barangays.png')
    plt.savefig(top_barangays_path, dpi=300)
    plt.close()
    print(f"Saved top barangays chart to: {top_barangays_path}")
    
    # ========== SOLUTION 4: INTERACTIVE PLOTLY VISUALIZATION ==========
    # Prepare data for Plotly
    plotly_data = []
    
    # Convert the data to long format for Plotly
    long_data = plot_data.reset_index().melt(
        id_vars='index', 
        value_vars=barangays,
        var_name='Barangay', 
        value_name='Votes'
    )
    long_data.rename(columns={'index': 'Candidate'}, inplace=True)
    
    # Create an interactive line chart
    fig = px.line(
        long_data, 
        x='Barangay', 
        y='Votes', 
        color='Candidate',
        title='Interactive Mayoral Votes per Barangay',
        labels={'Votes': 'Number of Votes', 'Barangay': 'Barangay'},
        height=600,
        markers=True
    )
    
    # Update layout for better readability
    fig.update_layout(
        xaxis_title='Barangay',
        yaxis_title='Number of Votes',
        legend_title='Candidates',
        xaxis={'tickangle': 45},
        hovermode='closest'
    )
    
    # Save as HTML
    interactive_path = os.path.join(graphs_folder, f'{clean_contest}_interactive.html')
    fig.write_html(interactive_path)
    print(f"Saved interactive visualization to: {interactive_path}")
    
    # ========== SOLUTION 5: CANDIDATE COMPARISON BAR CHART ==========
    # Calculate total votes per candidate
    candidate_totals = plot_data.sum(axis=1).sort_values(ascending=False)
    
    plt.figure(figsize=(12, 8))
    
    # Create horizontal bar chart of total votes per candidate
    bars = plt.barh(np.arange(len(candidate_totals)), candidate_totals.values, height=0.5)
    
    # Add labels to the bars
    for i, bar in enumerate(bars):
        plt.text(bar.get_width() + 500, bar.get_y() + bar.get_height()/2, 
                 f'{candidate_totals.values[i]:,}', 
                 va='center', fontsize=12)
    
    # Add labels and title
    plt.title('Total Votes per Mayoral Candidate', fontsize=16)
    plt.xlabel('Number of Votes', fontsize=14)
    plt.ylabel('Candidate', fontsize=14)
    plt.yticks(np.arange(len(candidate_totals)), candidate_totals.index)
    plt.grid(True, axis='x', linestyle='--', alpha=0.7)
    
    # Adjust layout and save
    plt.tight_layout()
    candidate_totals_path = os.path.join(graphs_folder, f'{clean_contest}_candidate_totals.png')
    plt.savefig(candidate_totals_path, dpi=300)
    plt.close()
    print(f"Saved candidate totals chart to: {candidate_totals_path}")
    
    print("All improved visualizations created successfully!")

# Run the function
create_improved_mayor_graphs("./results-per-position")
# Out:
# Found mayor file: ./results-per-position/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_results.csv
# Saved split line graph 1 to: ./mayor_visualizations/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_line_graph_group_1.png
# Saved split line graph 2 to: ./mayor_visualizations/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_line_graph_group_2.png
# Saved split line graph 3 to: ./mayor_visualizations/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_line_graph_group_3.png
# Saved split line graph 4 to: ./mayor_visualizations/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_line_graph_group_4.png
# Saved split line graph 5 to: ./mayor_visualizations/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_line_graph_group_5.png
# Saved split line graph 6 to: ./mayor_visualizations/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_line_graph_group_6.png
# Saved heatmap to: ./mayor_visualizations/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_heatmap.png
# Saved top barangays chart to: ./mayor_visualizations/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_top_barangays.png
# Saved interactive visualization to: ./mayor_visualizations/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_interactive.html
# Saved candidate totals chart to: ./mayor_visualizations/MAYOR_of_PANGASINAN__CITY_OF_SAN_CARLOS_candidate_totals.png
# All improved visualizations created successfully!

# %%
# Set up visualization directory
image_dir = Path("./election_visualizations_senator")
image_dir.mkdir(exist_ok=True)
print(f"Created visualization directory: {image_dir.absolute()}")

# Set matplotlib style
plt.style.use('seaborn-v0_8-whitegrid')  # Back to whitegrid (not pure white, has a light gray grid)
sns.set_palette("dark")  # Keep the dark palette for more saturated colors

# Set global figure size
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['savefig.dpi'] = 300  # High resolution for saved images

# Load the data
print("Loading election data...")
filepath = './results-per-position/SENATOR_of_PHILIPPINES_results.csv'
df = pd.read_csv(filepath)

print(f"Dataset shape: {df.shape}")
print(f"Number of candidates: {df.shape[0]}")

# Data Preparation
print("Preparing data for analysis...")
data = df.copy()

# Extract candidate names (remove numbers and party affiliations)
data['Clean_Name'] = data['Candidate'].str.extract(r'^\d+\.\s*(.+?)(?:\s*\([^)]+\))?$')

# Identify location columns (all columns except Candidate and Total)
location_cols = [col for col in data.columns if col not in ['Candidate', 'Clean_Name', 'Total']]

# Sort candidates by total votes
data_sorted = data.sort_values('Total', ascending=False).reset_index(drop=True)

# Display the top 15 candidates
print("\nTop 15 candidates by votes:")
top_15 = data_sorted[['Candidate', 'Clean_Name', 'Total']].head(15)
print(top_15.to_string(index=False))

# Save the top 15 candidates to CSV
top_15.to_csv(image_dir / "top_15_candidates.csv", index=False)
print(f"Saved: {image_dir / 'top_15_candidates.csv'}")

# Visualization 1: Top 15 Candidates by Total Votes
print("\nCreating visualization of top 15 candidates by votes...")

# Plot top 15 candidates
plt.figure(figsize=(12, 8))
top_15_plot = data_sorted.head(15).sort_values('Total')
# Changed to BuPu (blue to purple) - avoids yellow and pure white
bars = plt.barh(top_15_plot['Clean_Name'], top_15_plot['Total'], 
                color=plt.cm.BuPu(np.linspace(0.4, 0.9, 15)))  # Using range 0.4-0.9 to avoid too light colors

plt.title('Top 15 Senatorial Candidates by Total Votes', fontsize=16)
plt.xlabel('Total Votes', fontsize=12)
plt.ylabel('Candidate', fontsize=12)

# Add vote counts as labels
for i, bar in enumerate(bars):
    plt.text(bar.get_width() + 500, bar.get_y() + bar.get_height()/2, 
             f"{top_15_plot['Total'].iloc[i]:,}", 
             va='center', fontsize=10)

plt.tight_layout()

# Save the matplotlib figure
top_candidates_filepath = image_dir / "top_15_candidates.png"
plt.savefig(top_candidates_filepath, bbox_inches='tight')
print(f"Saved: {top_candidates_filepath}")
plt.close()

# Visualization 2: Top Barangays for #1 Candidate
print("\nAnalyzing top barangays for the #1 candidate...")

# Get the top candidate
top_candidate = data_sorted.iloc[0]
top_candidate_name = top_candidate['Clean_Name']
print(f"#1 Candidate: {top_candidate_name}")

# Create a dataframe of location votes for the top candidate
location_votes = pd.DataFrame({
    'Barangay': [loc.replace('-', ' ').title() for loc in location_cols],
    'Votes': [top_candidate[loc] for loc in location_cols]
})

# Sort by votes
location_votes = location_votes.sort_values('Votes', ascending=False).reset_index(drop=True)

# Display top 20 barangays
print("\nTop 20 barangays for the #1 candidate:")
print(location_votes.head(20).to_string(index=False))

# Save top barangays to CSV
location_votes.head(20).to_csv(image_dir / f"top_barangays_for_{top_candidate_name}.csv", index=False)
print(f"Saved: {image_dir / f'top_barangays_for_{top_candidate_name}.csv'}")

# Plot top 20 barangays
plt.figure(figsize=(14, 10))
top_20_barangays = location_votes.head(20).sort_values('Votes')
# Changed to BuPu (blue to purple) - avoids yellow and pure white
bars = plt.barh(top_20_barangays['Barangay'], top_20_barangays['Votes'], 
        color=plt.cm.BuPu(np.linspace(0.4, 0.9, 20)))  # Using range 0.4-0.9 to avoid too light colors

plt.title(f'Top 20 Barangays for {top_candidate_name}', fontsize=16)
plt.xlabel('Votes', fontsize=12)
plt.ylabel('Barangay', fontsize=12)

# Add vote counts as labels
for i, bar in enumerate(bars):
    plt.text(bar.get_width() + 20, bar.get_y() + bar.get_height()/2, 
             f"{top_20_barangays['Votes'].iloc[i]:,}", 
             va='center', fontsize=10)

plt.tight_layout()

# Save the matplotlib figure
top_barangays_filepath = image_dir / f"top_20_barangays_for_{top_candidate_name}.png"
plt.savefig(top_barangays_filepath, bbox_inches='tight')
print(f"Saved: {top_barangays_filepath}")
plt.close()

print("\nAnalysis complete!")
print(f"All visualizations and data have been saved to: {image_dir.absolute()}")
# Out:
# Created visualization directory: /home/ray/Desktop/local-election-san-carlos-analysis/election_visualizations_senator
# Loading election data...
# Dataset shape: (66, 88)
# Number of candidates: 66
# Preparing data for analysis...
#
# Top 15 candidates by votes:
#                          Candidate              Clean_Name  Total
#               5. AQUINO, BAM (KNP)             AQUINO, BAM  51346
#              59. SOTTO, TITO (NPC)             SOTTO, TITO  45514
#           63. TULFO, ERWIN (LAKAS)            TULFO, ERWIN  44365
#            1. ABALOS, BENHUR (PFP)          ABALOS, BENHUR  41272
#             18. CAYETANO, PIA (NP)           CAYETANO, PIA  40018
#              35. LAPID, LITO (NPC)             LAPID, LITO  38660
#          51. PANGILINAN, KIKO (LP)        PANGILINAN, KIKO  38253
#        28. GO, BONG GO    (PDPLBN)             GO, BONG GO  37206
#             33. LACSON, PING (IND)            LACSON, PING  36612
#         62. TULFO, BEN BITAG (IND)        TULFO, BEN BITAG  33661
# 11. BONG REVILLA,RAMON, JR.(LAKAS) BONG REVILLA,RAMON, JR.  32275
#               9. BINAY, ABBY (NPC)             BINAY, ABBY  31763
#           66. VILLAR, CAMILLE (NP)         VILLAR, CAMILLE  31538
#           39. MARCOS, IMEE R. (NP)         MARCOS, IMEE R.  30936
#       22. DELA ROSA, BATO (PDPLBN)         DELA ROSA, BATO  25111
# Saved: election_visualizations_senator/top_15_candidates.csv
#
# Creating visualization of top 15 candidates by votes...
# Saved: election_visualizations_senator/top_15_candidates.png
#
# Analyzing top barangays for the #1 candidate...
# #1 Candidate: AQUINO, BAM
#
# Top 20 barangays for the #1 candidate:
#       Barangay  Votes
#          Turac   1495
#         Bacnar   1393
#       Coliling   1286
#         Tarece   1261
#          Pagal   1131
#     Malacañang   1095
#      Calobaoan   1051
# Caoayan Kiling   1044
#          Agdao   1026
#       Quintong    995
#     Balite Sur    939
#       Bolingit    920
#          Cobol    920
#         Tandoc    892
#     Calomboyan    850
#       Pangpang    835
#       San Juan    814
#       Matagdem    805
#    Pangalangan    804
#      Magtaking    775
# Saved: election_visualizations_senator/top_barangays_for_AQUINO, BAM.csv
# Saved: election_visualizations_senator/top_20_barangays_for_AQUINO, BAM.png
#
# Analysis complete!
# All visualizations and data have been saved to: /home/ray/Desktop/local-election-san-carlos-analysis/election_visualizations_senator
